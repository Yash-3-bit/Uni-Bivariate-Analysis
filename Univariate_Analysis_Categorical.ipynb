# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
df.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# ## categorical data

# %% [markdown]
# ## bar graph

# %%
sns.countplot(data=df,x='neighbourhood_group')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(data=df,x='room_type')
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
sns.countplot(data=df,x='neighbourhood_group',hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# ## pie chart

# %%
df['room_type'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='room_type'>

# %%
df['neighbourhood_group'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='neighbourhood_group'>

# %%
df['neighbourhood_group'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df2 = sns.load_dataset('titanic')
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(data=df2,x='sex',hue='alive')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df2['sex'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='sex'>

# %%
df2['class'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='class'>
